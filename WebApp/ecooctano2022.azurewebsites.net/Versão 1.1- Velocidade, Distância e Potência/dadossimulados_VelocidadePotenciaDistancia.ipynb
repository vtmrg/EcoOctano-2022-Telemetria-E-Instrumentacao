# %%
# Copyright (c) Microsoft. All rights reserved.
# Licensed under the MIT license. See LICENSE file in the project root for full license information.

# !pip install azure-iot-device
# !pip install azure-iot-hub

import random
import random
import time
import os
from azure.iot.device import IoTHubDeviceClient, Message, MethodResponse

# The device connection string to authenticate the device with your IoT hub.
# Using the Azure CLI:
# az iot hub device-identity show-connection-string --hub-name {YourIoTHubName} --device-id MyNodeDevice --output table
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting azure-iot-device
#   Downloading azure_iot_device-2.11.0-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 28.2 MB/s
# Collecting paho-mqtt<2.0.0,>=1.4.0
#   Downloading paho-mqtt-1.6.1.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 9.9 MB/s
# Collecting deprecation<3.0.0,>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: PySocks in /usr/local/lib/python3.7/dist-packages (from azure-iot-device) (1.7.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from azure-iot-device) (2.23.0)
# Collecting urllib3<1.27,>=1.26.5
#   Downloading urllib3-1.26.11-py2.py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 60.5 MB/s
# Collecting requests-unixsocket<1.0.0,>=0.1.5
#   Downloading requests_unixsocket-0.3.0-py2.py3-none-any.whl (11 kB)
# Collecting janus
#   Downloading janus-1.0.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation<3.0.0,>=2.1.0->azure-iot-device) (21.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.20.0->azure-iot-device) (2022.6.15)
# Collecting requests<3.0.0,>=2.20.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.20.0->azure-iot-device) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.20.0->azure-iot-device) (2.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from janus->azure-iot-device) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation<3.0.0,>=2.1.0->azure-iot-device) (3.0.9)
# Building wheels for collected packages: paho-mqtt
#   Building wheel for paho-mqtt (setup.py) ... done
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.6.1-py3-none-any.whl size=62133 sha256=78e4462110107e2f64c013873c1a9e58e92db06774a81a05e3f9ab7d7cd4e71f
#   Stored in directory: /root/.cache/pip/wheels/d0/bf/ac/2b3f43f8c6fcd0f4ba5395397458c521eb0b52d33b574a5a40
# Successfully built paho-mqtt
# Installing collected packages: urllib3, requests, requests-unixsocket, paho-mqtt, janus, deprecation, azure-iot-device
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed azure-iot-device-2.11.0 deprecation-2.1.0 janus-1.0.0 paho-mqtt-1.6.1 requests-2.28.1 requests-unixsocket-0.3.0 urllib3-1.26.11
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting azure-iot-hub
#   Downloading azure_iot_hub-2.6.0-py2.py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 10.5 MB/s
# Collecting uamqp<2.0.0,>=1.2.14
#   Downloading uamqp-1.5.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 2.7 MB/s
# Collecting msrest<1.0.0,>=0.6.21
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 5.4 MB/s
# Collecting azure-core<2.0.0,>=1.10.0
#   Downloading azure_core-1.24.2-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 73.0 MB/s
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.10.0->azure-iot-hub) (4.1.1)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.10.0->azure-iot-hub) (2.28.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.10.0->azure-iot-hub) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from msrest<1.0.0,>=0.6.21->azure-iot-hub) (2022.6.15)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 785 kB/s
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest<1.0.0,>=0.6.21->azure-iot-hub) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.10.0->azure-iot-hub) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.10.0->azure-iot-hub) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.10.0->azure-iot-hub) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest<1.0.0,>=0.6.21->azure-iot-hub) (3.2.0)
# Installing collected packages: isodate, azure-core, uamqp, msrest, azure-iot-hub
# Successfully installed azure-core-1.24.2 azure-iot-hub-2.6.0 isodate-0.6.1 msrest-0.7.1 uamqp-1.5.3

# %%
CONNECTION_STRING = "HostName=Telemetria2022.azure-devices.net;DeviceId=myDeviceId;SharedAccessKey=I1Cs+Bbob8DPs/NX6OUaKkiPwSVGRtfBibmOQlF7JTw=";

# Define the JSON message to send to IoT Hub.
TEMPERATURE = 20.0
HUMIDITY = 60
MSG_TXT = '{{"velocidade": {velocidade},"potencia": {potencia}, "distancia": {distancia}}}'
MSG_TXT = '{{"dados": {dados}}}'


INTERVAL = 1


def create_client():
    # Create an IoT Hub client
    client = IoTHubDeviceClient.create_from_connection_string(CONNECTION_STRING)

    # Define a method request handler
    def method_request_handler(method_request):
        if method_request.name == "SetTelemetryInterval":
            try:
                global INTERVAL
                INTERVAL = int(method_request.payload)
            except ValueError:
                response_payload = {"Response": "Invalid parameter"}
                response_status = 400
            else:
                response_payload = {"Response": "Executed direct method {}".format(method_request.name)}
                response_status = 200
        else:
            response_payload = {"Response": "Direct method {} not defined".format(method_request.name)}
            response_status = 404

        method_response = MethodResponse.create_from_method_request(method_request, response_status, response_payload)
        client.send_method_response(method_response)

    try:
        # Attach the method request handler
        client.on_method_request_received = method_request_handler
    except:
        # Clean up in the event of failure
        client.shutdown()
        raise

    return client


def run_telemetry_sample(client):
    # This sample will send temperature telemetry every second
    print("IoT Hub device sending periodic messages")

    client.connect()

    while True:
        # Build the message with simulated telemetry values.
        velocidade = TEMPERATURE + (random.random() * 15)
        distancia = 4
        potencia = HUMIDITY + (random.random() * 20)
        msg_txt_formatted = MSG_TXT.format(velocidade=velocidade, potencia=potencia, distancia=distancia)
        message = Message(msg_txt_formatted)

        # Add a custom application property to the message.
        # An IoT hub can filter on these properties without access to the message body.
        # Send the message.
        print("Sending message: {}".format(message))
        client.send_message(message)
        print("Message sent")
        time.sleep(INTERVAL)


def main():
    print ("IoT Hub Quickstart #2 - Simulated device")
    print ("Press Ctrl-C to exit")

    # Instantiate the client. Use the same instance of the client for the duration of
    # your application
    client = create_client()

    # Send telemetry
    try:
        run_telemetry_sample(client)
    except KeyboardInterrupt:
        print("IoTHubClient sample stopped by user")
    finally:
        print("Shutting down IoTHubClient")
        client.shutdown()


if __name__ == '__main__':
    main()
# Out:
# IoT Hub Quickstart #2 - Simulated device
# Press Ctrl-C to exit
# IoT Hub device sending periodic messages
# Shutting down IoTHubClient
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-e692c63c4c91> in <module>()
#      87
#      88 if __name__ == '__main__':
# ---> 89     main()
#
# <ipython-input-5-e692c63c4c91> in main()
#      78     # Send telemetry
#      79     try:
# ---> 80         run_telemetry_sample(client)
#      81     except KeyboardInterrupt:
#      82         print("IoTHubClient sample stopped by user")
#
# <ipython-input-5-e692c63c4c91> in run_telemetry_sample(client)
#      56         distancia = 4
#      57         potencia = HUMIDITY + (random.random() * 20)
# ---> 58         msg_txt_formatted = MSG_TXT.format(velocidade=velocidade, potencia=potencia, distancia=distancia)
#      59         message = Message(msg_txt_formatted)
#      60
#
# KeyError: 'dados'
